# %%
import librosa
import numpy as np
from IPython.display import Audio
import torch

import nemo.collections.asr as nemo_asr

# %%
model = nemo_asr.models.EncDecCTCModelBPE.from_pretrained(
    model_name="nvidia/stt_en_fastconformer_ctc_large"
)
# Out:
# [NeMo I 2024-06-06 16:32:41 mixins:172] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2024-06-06 16:32:41 modelPT:176] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 1
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 20
#     min_duration: 0.1
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: fully_randomized
#     bucketing_batch_size: null
#
# [NeMo W 2024-06-06 16:32:41 modelPT:183] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
# ...

# %%
y, fs = librosa.load('LANDR- Meditation- Transcend 15 Mins-Balanced-Medium.mp3', sr=16000)
y.shape, fs
# Out:
# ((14401202,), 16000)

# %%
Audio(y[:y.shape[0] // 20], rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import math
from tqdm.notebook import tqdm

n = y.shape[0]
m = 20 * fs
k = math.ceil(n / m)
res = []
for i in tqdm(range(k)):
    res += model.transcribe(
        y[i*m : (i+1)*m],
        
    )
# Out:
# ...
# Transcribing: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.27s/it]
#
# ...
# Transcribing: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.22s/it]
#
# ...

# %%
res
# Out:
# ['',
#  'welcome to this meditation journey where you will find calm amidst the turbulence of the sea',
#  "i am andrew and i'll be your guide find a comfortable seated or lying position and gently close your eyes",
#  'begin by taking a few deep breaths allowing your body to relax and your mind to settle',
#  'imagine yourself on a small vessel itself',
#  'gently being carried by the swells the whole ocean seems to be an upheaval around you yet beneath the surface',
#  'the depth of the ocean is at rest visualize the vastness of the ocean',
#  'waves rising and falling but feel the stillness at its core',
#  'now select a mantra that resonates with you it could be a simple set',
#  'sound like hm or any word or phrase that brings you peace as you begin to',
#  'produce this mantra synchronize it with the rhythm of your breath',
#  'with each repetition of your mantra allow the music to quiet your mind',
# ...

# %%
print(
    ' '.join(
        list(
            filter(lambda x: len(x) > 0, res)
        )
    )
)
# Out:
# welcome to this meditation journey where you will find calm amidst the turbulence of the sea i am andrew and i'll be your guide find a comfortable seated or lying position and gently close your eyes begin by taking a few deep breaths allowing your body to relax and your mind to settle imagine yourself on a small vessel itself gently being carried by the swells the whole ocean seems to be an upheaval around you yet beneath the surface the depth of the ocean is at rest visualize the vastness of the ocean waves rising and falling but feel the stillness at its core now select a mantra that resonates with you it could be a simple set sound like hm or any word or phrase that brings you peace as you begin to produce this mantra synchronize it with the rhythm of your breath with each repetition of your mantra allow the music to quiet your mind let the soothing melodies wash over you guiding you deeper into a state of tranquillity feel the swells of the music mirroring the rise and fall of th
# ...
